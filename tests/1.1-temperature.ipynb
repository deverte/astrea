# %%
import numpy as np
import matplotlib.pyplot as plt

import nlte

from utils import *

# %%
population_nlte_1 = [0.0 for _ in range(52)]; population_nlte_1[0] = 1.0

count = int(10)
temperatures = np.linspace(1.0e1, 1.0e10, num=count)
electron_number_densities = np.full(count, 1.0e4)

# %%
b_factors = calculate_b_factors(
    population_nlte_1,
    temperatures,
    electron_number_densities,
)
# Out:
# /home/deverte/Projects/progs/astro/nlte/tests/utils.py:26: RuntimeWarning: divide by zero encountered in divide
#   b_factors[i] = population_nlte_2 / population_lte

# %%
for i, key in enumerate(nlte.Oxygen.keys):
    plt.plot(b_factors.T[i], label=key)
plt.legend()
plt.show()

# %%
plot_b_factors(b_factors, "12P3P4")
